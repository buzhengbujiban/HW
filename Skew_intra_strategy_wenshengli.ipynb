# %% [markdown]
# # Earnings Return Prediction Challenge - Starter Template (v7 20240419)
#
# In this project we will train a model to predict the stock return on the day of earnings for US companies. This template contains code to get you started with the project.

# %% [markdown]
# ## Standard imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Notebook configuration
# - Please set the **<span style="color:red">config['enddate']</span>** to the most recent Friday. Do not change any other config parameters.
#
# - The environment might take around one minute to load
# - The  **Operators** are functions that can be used to apply a series of transformations to a data variable or alpha.
# > [Introduction to Operators](https://trexsim.com/trexsim/pysim/tutorial2022/operators.html)
# >
# > Find all available  operators in the [operators list](https://www.trexsim.com/trexsim/pysim/comptutorial/operators.html)

# %%
import operators as op              # find all available operators, https://www.trexsim.com/trexsim/pysim/comptutorial/operators.html
import utilities as utils
import strategy_utilities as sutil
from strategy_research import load_env

config = {
    'enddate': 20240517,            # Please setting the config['enddate'] to the most recent Friday.
    'region': 'USA',
    'universe': 'top3000',
    'delay': 0,
    'booksize':1e6,
    'refit_interval': 'OneQuarter',
    'filter_function_uuid': 'none',
    'fit_function_uuid': 'none',
    'pp_function_uuid': 'none',
    'tf_function_uuid': 'none',
    'postalpha': False,
    'compress': False,    
    'load_cache': False,
    'save_cache': False,
    'skip_post_strategy': True,
    'skip_test_cases': True,
    'strat_dir': './'
}

def tf_function(preA, data): return preA
function_dict = {'tf_function': tf_function}

env = load_env('USA')
data = sutil.create_strategy_data(function_dict, config, 'full', env, use_pre_compressed=True)
data = sutil.add_builtin_functions(data, function_dict, config, env)
# Out:
# is container True
# Variable numdates is loaded from /home/newprod/production/data/USA/simvars/numdates/numdates.20240517.raw.mat
# Variable numstocks is loaded from /home/newprod/production/data/USA/simvars/numstocks/numstocks.20240517.raw.mat
# Variable dates is loaded from /home/newprod/production/data/USA/simvars/dates/dates.20240517.raw.mat
# Variable dates is loaded from /home/newprod/production/data/USA/simvars/dates/dates.20240517.adj_amend.mat 4625
# Variable numdates is loaded from /home/newprod/production/data/USA/simvars/numdates/numdates.20240517.adj_amend.mat 4625
# Variable startdate is loaded from /home/newprod/production/data/USA/simvars/startdate/startdate.20240517.adj_amend.mat 4625
# Variable enddate is loaded from /home/newprod/production/data/USA/simvars/enddate/enddate.20240517.adj_amend.mat 4625
# Variable spread_timeweighted_allday is loaded from /home/newprod/production/data/USA/simvars/spread_timeweighted_allday/spread_timeweighted_allday.20240517.adj_amend.ci 4625
# Variable numstocks is loaded from /home/newprod/production/data/USA/simvars/numstocks/numstocks.20240517.adj_amend.mat 4625
# Variable volume is loaded from /home/newprod/production/data/USA/simvars/volume/volume.20240517.adj_amend.ci 4625
# Variable shsfloat is loaded from /home/newprod/production/data/USA/simvars/shsfloat/shsfloat.20240517.adj_amend.ci 4625
# Variable shsout is loaded from /home/newprod/production/data/USA/simvars/shsout/shsout.20240517.adj_amend.ci 4625
# Variable open is loaded from /home/newprod/production/data/USA/simvars/open/open.20240517.adj_amend.ci 4625
# Variable low is loaded from /home/newprod/production/data/USA/simvars/low/low.20240517.adj_amend.ci 4625
# Variable high is loaded from /home/newprod/production/data/USA/simvars/high/high.20240517.adj_amend.ci 4625
# Variable close is loaded from /home/newprod/production/data/USA/simvars/close/close.20240517.adj_amend.ci 4625
# Variable mktcap is loaded from /home/newprod/production/data/USA/simvars/mktcap/mktcap.20240517.adj_amend.ci 4625
# Variable uopen is loaded from /home/newprod/production/data/USA/simvars/uopen/uopen.20240517.adj_amend.ci 4625
# Variable uvwap is loaded from /home/newprod/production/data/USA/simvars/uvwap/uvwap.20240517.adj_amend.ci 4625
# Variable uclose is loaded from /home/newprod/production/data/USA/simvars/uclose/uclose.20240517.adj_amend.ci 4625
# Variable uvolume is loaded from /home/newprod/production/data/USA/simvars/uvolume/uvolume.20240517.adj_amend.ci 4625
# Variable adjfactor is loaded from /home/newprod/production/data/USA/simvars/adjfactor/adjfactor.20240517.adj_amend.ci 4625
# Variable adjfactor_price_only is loaded from /home/newprod/production/data/USA/simvars/adjfactor_price_only/adjfactor_price_only.20240517.adj_amend.ci 4625
# Variable cashdvd is loaded from /home/newprod/production/data/USA/simvars/cashdvd/cashdvd.20240517.adj_amend.ci 4625
# Variable industry is loaded from /home/newprod/production/data/USA/simvars/industry/industry.20240517.adj_amend.ci 4625
# Variable sector is loaded from /home/newprod/production/data/USA/simvars/sector/sector.20240517.adj_amend.ci 4625
# Variable subindustry is loaded from /home/newprod/production/data/USA/simvars/subindustry/subindustry.20240517.adj_amend.ci 4625
# Variable vwap is loaded from /home/newprod/production/data/USA/simvars/vwap/vwap.20240517.adj_amend.ci 4625
# Variable top100 is loaded from /home/newprod/production/data/USA/simvars/top100/top100.20240517.adj_amend.ci 4625
# Variable top250 is loaded from /home/newprod/production/data/USA/simvars/top250/top250.20240517.adj_amend.ci 4625
# Variable top500 is loaded from /home/newprod/production/data/USA/simvars/top500/top500.20240517.adj_amend.ci 4625
# Variable top1000 is loaded from /home/newprod/production/data/USA/simvars/top1000/top1000.20240517.adj_amend.ci 4625
# Variable top1500 is loaded from /home/newprod/production/data/USA/simvars/top1500/top1500.20240517.adj_amend.ci 4625
# Variable top1750 is loaded from /home/newprod/production/data/USA/simvars/top1750/top1750.20240517.adj_amend.ci 4625
# Variable top2000 is loaded from /home/newprod/production/data/USA/simvars/top2000/top2000.20240517.adj_amend.ci 4625
# Variable top2500 is loaded from /home/newprod/production/data/USA/simvars/top2500/top2500.20240517.adj_amend.ci 4625
# Variable top3000 is loaded from /home/newprod/production/data/USA/simvars/top3000/top3000.20240517.adj_amend.ci 4625
# Variable top500_2000 is loaded from /home/newprod/production/data/USA/simvars/top500_2000/top500_2000.20240517.adj_amend.ci 4625
# Variable growth1200 is loaded from /home/newprod/production/data/USA/simvars/growth1200/growth1200.20240517.adj_amend.ci 4625
# Variable value1200 is loaded from /home/newprod/production/data/USA/simvars/value1200/value1200.20240517.adj_amend.ci 4625
# Variable sp500 is loaded from /home/newprod/production/data/USA/simvars/sp500/sp500.20240517.adj_amend.ci 4625
# Variable ret1 is loaded from /home/newprod/production/data/USA/simvars/ret1/ret1.20240517.adj_amend.ci 4625
# Variable ret5 is loaded from /home/newprod/production/data/USA/simvars/ret5/ret5.20240517.adj_amend.ci 4625
# Variable vol20 is loaded from /home/newprod/production/data/USA/simvars/vol20/vol20.20240517.adj_amend.ci 4625
# Variable locates_ms_avshs is loaded from /home/newprod/production/data/USA/simvars/locates_ms_avshs/locates_ms_avshs.20240517.adj_amend.ci 4625
# Variable locates_ms_rebate is loaded from /home/newprod/production/data/USA/simvars/locates_ms_rebate/locates_ms_rebate.20240517.adj_amend.ci 4625
# Variable barra_hbta is loaded from /home/newprod/production/data/USA/simvars/barra_hbta/barra_hbta.20240517.adj_amend.ci 4625
# Variable barra_beta is loaded from /home/newprod/production/data/USA/simvars/barra_beta/barra_beta.20240517.adj_amend.ci 4625
# Variable barra_srisk is loaded from /home/newprod/production/data/USA/simvars/barra_srisk/barra_srisk.20240517.adj_amend.ci 4625
# Variable barra_trisk is loaded from /home/newprod/production/data/USA/simvars/barra_trisk/barra_trisk.20240517.adj_amend.ci 4625
# Variable barra_volatility is loaded from /home/newprod/production/data/USA/simvars/barra_volatility/barra_volatility.20240517.adj_amend.ci 4625
# Variable barra_momentum is loaded from /home/newprod/production/data/USA/simvars/barra_momentum/barra_momentum.20240517.adj_amend.ci 4625
# Variable barra_size is loaded from /home/newprod/production/data/USA/simvars/barra_size/barra_size.20240517.adj_amend.ci 4625
# Variable barra_sizenonl is loaded from /home/newprod/production/data/USA/simvars/barra_sizenonl/barra_sizenonl.20240517.adj_amend.ci 4625
# Variable barra_tradeact is loaded from /home/newprod/production/data/USA/simvars/barra_tradeact/barra_tradeact.20240517.adj_amend.ci 4625
# Variable barra_growth is loaded from /home/newprod/production/data/USA/simvars/barra_growth/barra_growth.20240517.adj_amend.ci 4625
# Variable barra_earnyld is loaded from /home/newprod/production/data/USA/simvars/barra_earnyld/barra_earnyld.20240517.adj_amend.ci 4625
# Variable barra_value is loaded from /home/newprod/production/data/USA/simvars/barra_value/barra_value.20240517.adj_amend.ci 4625
# Variable barra_earnvar is loaded from /home/newprod/production/data/USA/simvars/barra_earnvar/barra_earnvar.20240517.adj_amend.ci 4625
# Variable barra_leverage is loaded from /home/newprod/production/data/USA/simvars/barra_leverage/barra_leverage.20240517.adj_amend.ci 4625
# Variable barra_currsen is loaded from /home/newprod/production/data/USA/simvars/barra_currsen/barra_currsen.20240517.adj_amend.ci 4625
# Variable barra_yield is loaded from /home/newprod/production/data/USA/simvars/barra_yield/barra_yield.20240517.adj_amend.ci 4625
# Variable barra_nonestu is loaded from /home/newprod/production/data/USA/simvars/barra_nonestu/barra_nonestu.20240517.adj_amend.ci 4625
# Variable barra_ind1_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind1_id/barra_ind1_id.20240517.adj_amend.ci 4625
# Variable barra_ind1_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind1_rev/barra_ind1_rev.20240517.adj_amend.ci 4625
# Variable barra_ind2_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind2_id/barra_ind2_id.20240517.adj_amend.ci 4625
# Variable barra_ind2_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind2_rev/barra_ind2_rev.20240517.adj_amend.ci 4625
# Variable barra_ind3_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind3_id/barra_ind3_id.20240517.adj_amend.ci 4625
# Variable barra_ind3_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind3_rev/barra_ind3_rev.20240517.adj_amend.ci 4625
# Variable barra_ind4_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind4_id/barra_ind4_id.20240517.adj_amend.ci 4625
# Variable barra_ind4_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind4_rev/barra_ind4_rev.20240517.adj_amend.ci 4625
# Variable barra_ind5_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind5_id/barra_ind5_id.20240517.adj_amend.ci 4625
# Variable barra_ind5_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind5_rev/barra_ind5_rev.20240517.adj_amend.ci 4625
# Variable indNameMap is loaded from /home/newprod/production/data/USA/simvars/indNameMap/indNameMap.20240517.adj_amend.txt 4625
# Variable prod_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_alpha_ids/prod_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_alpha_is_deads is loaded from /home/newprod/production/data/USA/simvars/prod_alpha_is_deads/prod_alpha_is_deads.20240517.adj_amend.mat 4625
# Variable prod_d0_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d0_alpha_ids/prod_d0_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_d1_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d1_alpha_ids/prod_d1_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_post_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_post_alpha_ids/prod_post_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_post_alpha_is_deads is loaded from /home/newprod/production/data/USA/simvars/prod_post_alpha_is_deads/prod_post_alpha_is_deads.20240517.adj_amend.mat 4625
# Variable prod_d0_post_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d0_post_alpha_ids/prod_d0_post_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_d1_post_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d1_post_alpha_ids/prod_d1_post_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_forecast_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_forecast_alpha_ids/prod_forecast_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_forecast_alpha_is_deads is loaded from /home/newprod/production/data/USA/simvars/prod_forecast_alpha_is_deads/prod_forecast_alpha_is_deads.20240517.adj_amend.mat 4625
# Variable prod_d0_forecast_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d0_forecast_alpha_ids/prod_d0_forecast_alpha_ids.20240517.adj_amend.mat 4625
# Variable prod_d1_forecast_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d1_forecast_alpha_ids/prod_d1_forecast_alpha_ids.20240517.adj_amend.mat 4625
# Variable dates is loaded from /home/newprod/production/data/USA/simvars/dates/dates.20240517.adj_amend.mat 4625
# Shift data for d0
# Shifting spread_timeweighted_allday by one day
# Shifting mktcap by one day
# Shifting top100 by one day
# Shifting top250 by one day
# Shifting top500 by one day
# Shifting top1000 by one day
# Shifting top1500 by one day
# Shifting top1750 by one day
# Shifting top2000 by one day
# Shifting top2500 by one day
# Shifting top3000 by one day
# Shifting top500_2000 by one day
# Shifting growth1200 by one day
# Shifting value1200 by one day
# Shifting sp500 by one day
# Shifting locates_ms_avshs by one day
# Shifting locates_ms_rebate by one day
# Shifting barra_hbta by one day
# Shifting barra_beta by one day
# Shifting barra_srisk by one day
# Shifting barra_trisk by one day
# Shifting barra_volatility by one day
# Shifting barra_momentum by one day
# Shifting barra_size by one day
# Shifting barra_sizenonl by one day
# Shifting barra_tradeact by one day
# Shifting barra_growth by one day
# Shifting barra_earnyld by one day
# Shifting barra_value by one day
# Shifting barra_earnvar by one day
# Shifting barra_leverage by one day
# Shifting barra_currsen by one day
# Shifting barra_yield by one day
# Shifting barra_nonestu by one day
# Shifting barra_ind1_id by one day
# Shifting barra_ind1_rev by one day
# Shifting barra_ind2_id by one day
# Shifting barra_ind2_rev by one day
# Shifting barra_ind3_id by one day
# Shifting barra_ind3_rev by one day
# Shifting barra_ind4_id by one day
# Shifting barra_ind4_rev by one day
# Shifting barra_ind5_id by one day
# Shifting barra_ind5_rev by one day
# NOT Shifting prod_forecast_alpha_ids
# NOT Shifting prod_forecast_alpha_is_deads
# NOT Shifting prod_d0_forecast_alpha_ids
# NOT Shifting prod_d1_forecast_alpha_ids
# The alpha list is reconciled
# Alpha list size: 117251
# Rendering ndarray read-only

# %% [markdown]
# ## **Mask**
#
# Most data variables at Trexquant are 2D matrices with dimensions _num\_stocks_ x _num\_dates_. We want to filter on the dates when earnings were announced and convert the 2D matrix to a vector so that it can be used in an ML model.
#
# To find the earnings date we use the data variable [trading_days_til_next_ann](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/trading_days_til_next_ann/). We also require the time of announcement which we get from the data variable [fs_next_ann_time](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/fs_next_ann_time/). We use the following logic to construct the mask:
# 1. If the annoucement time is before the trading time (1500), set the earnings return day as today.
# 2. If the annoucement time is after the trading time (1500), set the earnings return day as the next day.
#
# The code in the cell below constructs the mask

# %%
### ---- ---- ---- ---- No need to modify the code below ---- ---- ---- ---- ###

# contruct earning mask based on trading_days_til_next_ann
valid_mask = (data['load_simvar_hhmm']('trading_days_til_next_ann') == 1)
fs_next_ann_time = data['load_simvar_hhmm']('fs_next_ann_time')

# based on trading_days_til_next_ann and fs_next_ann_time
# delay one day if earnings is announced after we trade
valid_effect_mask = np.zeros_like(valid_mask, dtype=np.float32)
for si, di in zip(*np.where((valid_mask == 1) & (data['valids']))):

    # skip if we are unable to get the target
    if di + data['delay'] >= data['numdates']:
        continue

    time = fs_next_ann_time[si, di]

    if time <= 1500:
        target_di = di
    elif time > 1500 and di + 1 < data['numdates']:
        target_di = di+1
    if valid_effect_mask[si, target_di] != 1:
        valid_effect_mask[si, target_di] = 1
        
bet_days_mask = valid_effect_mask==1
bet_days_mask = op.at_nan2zero(bet_days_mask*1.0)
flatten_mask = (bet_days_mask==1.0)

# %% [markdown]
# ## **Target**
#
# For this challenge we will use one-day forward ret1_excess as the target
# - target columns: `target`, which is the forward [ret1_excess](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/ret1_excess/)
# - dates: `dates` column is the masked dates, which is the day we want to enter our position before the earning announcement.
# - stock index: `si`
# - date index: `di`
# - `[si,di]` data point indicates that we want to enter into the position for the stock at si th index and di th date just before the company announces its results

# %%
### ---- ---- ---- ---- No need to modify the code below ---- ---- ---- ---- ###

ret1_excess = data['load_simvar_hhmm']('ret1_excess')
fwd_ret = op.ts_delay((ret1_excess),-1) # one day forward ret1_excess

# modify mask to remove points where target is invalid
flatten_mask[np.isnan(fwd_ret)] = False  
target = fwd_ret[flatten_mask]

# put target into the dataframe
df = pd.DataFrame()
df['target'] = target

num_of_stocks, num_of_dates = ret1_excess.shape
si_list = np.array([list(np.arange(num_of_stocks))]*num_of_dates).transpose()
di_list = np.array([list(np.arange(num_of_dates))]*num_of_stocks)

df['si'] = si_list[flatten_mask]
df['di'] = di_list[flatten_mask]
dates_mat = np.tile(data['dates'], (num_of_stocks,1))
df['dates'] = dates_mat[flatten_mask]

# %% [markdown]
# ## **Features**
#
# For this challenge you can use any of the data variables available in the [data description](https://trexsim.com/trexsim/pysim/data_description/USA/).
# You may further apply any transformations to the data variables that you deem appropriate.
#
# Please keep in mind that **all features used must be dimensionless**. Features that have dimensions of price of number of shares are subject to adjustment which introduces a forward bias. An easy way to check if a data variable is subject to adjustment is to check if there is anything in the `adjfactor_type` column in the data description.
# Features which are subject to adjustment can be normalized using operators like `ts_zscore`, `ts_norm` and `ts_std_normalized`. Find all available operators in [operators list](https://www.trexsim.com/trexsim/pysim/comptutorial/operators.html).
#
# You can combine existing features and apply operators to make new features as long as the transformations are reasonable.
#
# In the followint cell, you will see 3 feature used in the benchmark model.
# - [ret1](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/ret1/): On day return.
# - [linkup_job_active_count](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/linkup_job_active_count/): number of active jobs.

# %%
### ---- ---- ---- ---- Featurs used in the Benchmark model ---- ---- ---- ---- ###

####### feature 1: tsz_ret1
ret1 = data['load_simvar_hhmm']('ret1')                    # Load data variable
tsz_ret1 = op.at_nan2zero(op.ts_zscore(ret1, 21))          # Calculate the feature
df['tsz_ret1'] = tsz_ret1[flatten_mask]                    # Apply the mask to the feature and save it in the dataframe.

####### feature 2: tsz_ret1_delay1
tsz_ret1_d1 = op.at_nan2zero(op.ts_zscore(op.ts_delay(ret1,1), 21))       
df['tsz_ret1_d1'] = tsz_ret1_d1[flatten_mask] 

####### feature 3: linkup_job_active_count
linkup_job_active_count = data['load_simvar_hhmm']('linkup_job_active_count')
linkup_job_active_count = op.at_nan2zero(op.ts_zscore(op.ts_fill(linkup_job_active_count), 21))
df['linkup_job_active_count'] = linkup_job_active_count[flatten_mask]

# name of all features
features_ls = [col for col in df.columns if col not in ['target', 'si', 'di', 'dates']]
print(f"Current features: {features_ls}")
# Out:
# Current features: ['tsz_ret1', 'tsz_ret1_d1', 'linkup_job_active_count']

# %% [markdown]
# #### **New Features**
#
# Here is an example on adding a new technical feature to the model:
#
# - [CloseSpread_vwap](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/CloseSpread_vwap/): close minus vwap divided by close

# %%
## ---- ---- ---- ---- Create your new featurs here ---- ---- ---- ---- ###
industry = data['load_simvar_hhmm']('industry')

skew_volume_afternoon = data['load_simvar_hhmm']('skew_volume_afternoon')
skew_volume_afternoon_mean = op.at_nan2zero(op.cs_zscore((op.ts_mean(op.cs_zscore(skew_volume_afternoon), 20))))
df['skew_volume_afternoon_mean'] = skew_volume_afternoon_mean[flatten_mask]  


downvolume_retskew_allday = data['load_simvar_hhmm']('downvolume_retskew_allday')
downvolume_retskew_allday_mean = op.at_nan2zero(op.cs_zscore((op.ts_mean(op.cs_zscore(downvolume_retskew_allday), 60))))
df['downvolume_retskew_allday_mean'] = downvolume_retskew_allday_mean[flatten_mask] # down is very better  # volume weighted is slightly better

downvolume_retskew_allday = data['load_simvar_hhmm']('downvolume_retskew_allday')
downvolume_retskew_allday_std = op.at_nan2zero(op.cs_zscore((op.ts_std(op.cs_zscore(downvolume_retskew_allday), 60))))
df['downvolume_retskew_allday_std'] = downvolume_retskew_allday_std[flatten_mask]  # std is better



macd_30min_180min_skew_volume_1d = data['load_simvar_hhmm']('macd_30min_180min_skew_volume_1d')
macd_30min_180min_skew_volume_1d_std = op.at_nan2zero(op.cs_zscore(op.cs_rank(op.ts_std(op.cs_zscore(macd_30min_180min_skew_volume_1d), 120))))
df['macd_30min_180min_skew_volume_1d_std'] = macd_30min_180min_skew_volume_1d_std[flatten_mask]


num_tc_buy_emo_tsz_10min_skw = data['load_simvar_hhmm']('num_tc_buy_emo_tsz_10min_skw')
num_tc_buy_emo_tsz_10min_skw_mean = op.at_nan2zero(op.cs_zscore(op.cs_rank(num_tc_buy_emo_tsz_10min_skw)))
df['num_tc_buy_emo_tsz_10min_skw_mean'] = num_tc_buy_emo_tsz_10min_skw_mean[flatten_mask]


df.replace([np.inf, -np.inf], np.nan, inplace=True)

# name of all features
features_ls = [col for col in df.columns if col not in ['target', 'si', 'di', 'dates']]
print(f"Current features: {features_ls}")

# %%
import pandas as pd
import matplotlib.pyplot as plt

def dataframe_summary(df):
    # 打印每个DataFrame的列名
    # print("Columns:")
    # print(df.columns)
    # print()

    # # 打印每列的统计量
    # print("Statistics:")
    # print(df.describe())
    # print()

    # # 计算每列的NAN值个数
    # print("Number of NANs:")
    # print(df.isnull().sum())
    # print()

    # 绘制箱线图
    df.boxplot()
    plt.title("Boxplot of DataFrame")
    plt.xticks(rotation=45)
    plt.show()

# 查看DataFrame的摘要信息
dataframe_summary(df[features_ls])

# %%
# %matplotlib inline
plt.figure(figsize=(5, 4)) # adjust the figure size of the heatmap
correlation_matrix = df[features_ls].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.savefig('corr.png')

# %% [markdown]
# ## **Training and validation**
# - Training period: From 2006 to 2016 (11 years)
# - Validation period: From 2017 to 2020 (4 years)

# %%
train_startdate = 20060101
train_enddate = 20161231

valid_startdate = 20170101
valid_enddate = 20201231

# split the df according to the periods of train/valid
train_mask = (df['dates'] >= train_startdate) & (df['dates'] <= train_enddate)
valid_mask = (df['dates'] >= valid_startdate) & (df['dates'] <= valid_enddate)

df_train = df[train_mask]
df_valid = df[valid_mask]
        
X_train,Y_train = df_train[features_ls].to_numpy(),df_train['target'].to_numpy()
X_valid,Y_valid = df_valid[features_ls].to_numpy(),df_valid['target'].to_numpy()

train_si,train_di = df_train['si'].values, df_train['di'].values
valid_si,valid_di = df_valid['si'].values, df_valid['di'].values

# %% [markdown]
# ## **Model**

# %%
### ---- ---- ---- ---- Train your Model ---- ---- ---- ---- ###

from sklearn.ensemble import GradientBoostingRegressor

# train the model
regressor = GradientBoostingRegressor(n_estimators=400, learning_rate=0.1, max_depth=1, random_state=42)
regressor.fit(X_train, Y_train)

# predict
YPRED_train = regressor.predict(X_train)
YPRED_valid = regressor.predict(X_valid)

# alpha
alpha = np.full_like(data['ret1'], np.nan, dtype='float32', order='F')
alpha[train_si, train_di] = YPRED_train
alpha[valid_si, valid_di] = YPRED_valid

# accuracy
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score
acc_train = accuracy_score(Y_train>=0, YPRED_train>=0)
acc_valid = accuracy_score(Y_valid>=0, YPRED_valid>=0)
print(f'Accuracy Train: {acc_train :>.3%}')
print(f'Accuracy Valid: {acc_valid :>.3%}')

# %% [markdown]
# ## **Simulation**
#
# ##### Post Processing (PP) function
# - PP function applies the final risk-management constraints on the signal and makes our signal tradeable in real markets
# - PP function reduces the turnover and increases the liquidity which reduces the slippage costs

# %%
# PP function - No need to modify the code below

def post_processing(data, preA, booksize):
    lookback = 252
    
    apply_locates = data['apply_locates']
    preA1 = np.copy(preA)
    preA1 *= data['valids']
  
    postA = op.at_nan2zero(preA1)
    postA = op.ts_mean_exp(op.at_nan2zero(postA), 5, 2/5)
    
    postA = op.cs_poslimit(postA, 0.1)
    postA = op.cs_indneut(postA, data['sector'])
    postA = op.cs_shrink_balance(postA)                                            

    long_scaler = op.ts_max(np.nansum(postA*(postA>0),axis=0),lookback)            
    short_scaler = op.ts_max(np.nansum(np.abs(postA)*(postA<0),axis=0),lookback)   
    scaler = np.maximum(long_scaler,short_scaler)                                  
    postA = postA/scaler * booksize                                                
    
    postA = op.op_vmcont(postA, data['valids'], data['close'], data['vol20'],
                         maxtrd=0.05*(booksize/1e9), maxpos=0.5*(booksize/1e9))
    postA = op.tc_hump(postA, data['close'], hump_factor=1.0)                      
    postA = op.cs_shrink_balance(postA)                                            

    long_scaler = op.ts_max(np.nansum(postA*(postA>0),axis=0),lookback)
    short_scaler = op.ts_max(np.nansum(np.abs(postA)*(postA<0),axis=0),lookback)
    scaler = np.maximum(long_scaler,short_scaler)
    postA = postA/scaler * booksize

    postA = op.cs_poslimit(postA, 0.1)
    postA = op.cs_shrink_balance(postA)                                            
    postA = apply_locates(postA, data, data['locate_utilization_rate'], data['max_rebate_rate'])
    return postA

# %%
### ---- ---- ---- ---- No need to modify the code below ---- ---- ---- ---- ###
# simulation
postA = post_processing(data,alpha,data['booksize'])
postA[:, np.where(data['dates']>valid_enddate)[0][0]:]=np.nan # nan out values after valid_enddate
simres = op.op_simulate(data,postA,0,liq_on_valid_days=True,calc_liqn=True,slippage=True, slippage_model='fraction_spread', fraction_spread=0.2)

# simulation results
simres_train = op.cut_simres(simres,startdate=train_startdate,enddate=train_enddate)
simres_valid = op.cut_simres(simres,startdate=valid_startdate,enddate=valid_enddate)

# pnl plots
# %matplotlib inline
op.op_plot(op.cut_simres(simres,startdate=train_startdate,enddate=train_enddate),label='train period')
op.op_plot(op.cut_simres(simres,startdate=valid_startdate,enddate=valid_enddate),label='valid period')

# %% [markdown]
# ## **Summary**

# %%
# Summary on the Metrics
metrics = ['ir','ret','tvr','dd','liqn']
metrics_train = [acc_train*100]+[simres_train[mtc][-1] if isinstance(simres_train[mtc], np.ndarray) else simres_train[mtc] for mtc in metrics]
metrics_valid = [acc_valid*100]+[simres_valid[mtc][-1] if isinstance(simres_valid[mtc], np.ndarray) else simres_valid[mtc] for mtc in metrics]

pd.options.display.float_format = '{:.3f}'.format
simres_df = pd.DataFrame({"train":metrics_train,"valid":metrics_valid}, index=['accuracy']+metrics)
display(simres_df.T)

# %%
# name of all features
features_ls = [col for col in df.columns if col not in ['target', 'si', 'di', 'dates']]
print(f"Current features: {features_ls}")

# %%
regressor.feature_importances_

# %% [markdown]
# # Earnings Return Prediction Challenge - Starter Template (v7 20240419)
#
# In this project we will train a model to predict the stock return on the day of earnings for US companies. This template contains code to get you started with the project.

# %% [markdown]
# ## Standard imports

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Notebook configuration
# - Please set the **<span style="color:red">config['enddate']</span>** to the most recent Friday. Do not change any other config parameters.
#
# - The environment might take around one minute to load
# - The  **Operators** are functions that can be used to apply a series of transformations to a data variable or alpha.
# > [Introduction to Operators](https://trexsim.com/trexsim/pysim/tutorial2022/operators.html)
# >
# > Find all available  operators in the [operators list](https://www.trexsim.com/trexsim/pysim/comptutorial/operators.html)

# %%
import operators as op              # find all available operators, https://www.trexsim.com/trexsim/pysim/comptutorial/operators.html
import utilities as utils
import strategy_utilities as sutil
from strategy_research import load_env

config = {
    'enddate': 20241004,            # Please setting the config['enddate'] to the most recent Friday.
    'region': 'USA',
    'universe': 'top3000',
    'delay': 0,
    'booksize':1e6,
    'refit_interval': 'OneQuarter',
    'filter_function_uuid': 'none',
    'fit_function_uuid': 'none',
    'pp_function_uuid': 'none',
    'tf_function_uuid': 'none',
    'postalpha': False,
    'compress': False,    
    'load_cache': False,
    'save_cache': False,
    'skip_post_strategy': True,
    'skip_test_cases': True,
    'strat_dir': './'
}

def tf_function(preA, data): return preA
function_dict = {'tf_function': tf_function}

env = load_env('USA')
data = sutil.create_strategy_data(function_dict, config, 'full', env, use_pre_compressed=False)
data = sutil.add_builtin_functions(data, function_dict, config, env)
# Out:
# is container True
# Variable numdates is loaded from /home/newprod/production/data/USA/simvars/numdates/numdates.20241004.raw.mat
# Variable numstocks is loaded from /home/newprod/production/data/USA/simvars/numstocks/numstocks.20241004.raw.mat
# Variable dates is loaded from /home/newprod/production/data/USA/simvars/dates/dates.20241004.raw.mat
# Variable dates is loaded from /home/newprod/production/data/USA/simvars/dates/dates.20241004.adj_amend.mat 4721
# Variable numdates is loaded from /home/newprod/production/data/USA/simvars/numdates/numdates.20241004.adj_amend.mat 4721
# Variable startdate is loaded from /home/newprod/production/data/USA/simvars/startdate/startdate.20241004.adj_amend.mat 4721
# Variable enddate is loaded from /home/newprod/production/data/USA/simvars/enddate/enddate.20241004.adj_amend.mat 4721
# Variable spread_timeweighted_allday is loaded from /home/newprod/production/data/USA/simvars/spread_timeweighted_allday/spread_timeweighted_allday.20241004.adj_amend.ci 4721
# Variable numstocks is loaded from /home/newprod/production/data/USA/simvars/numstocks/numstocks.20241004.adj_amend.mat 4721
# Variable volume is loaded from /home/newprod/production/data/USA/simvars/volume/volume.20241004.adj_amend.ci 4721
# Variable shsfloat is loaded from /home/newprod/production/data/USA/simvars/shsfloat/shsfloat.20241004.adj_amend.ci 4721
# Variable shsout is loaded from /home/newprod/production/data/USA/simvars/shsout/shsout.20241004.adj_amend.ci 4721
# Variable open is loaded from /home/newprod/production/data/USA/simvars/open/open.20241004.adj_amend.ci 4721
# Variable low is loaded from /home/newprod/production/data/USA/simvars/low/low.20241004.adj_amend.ci 4721
# Variable high is loaded from /home/newprod/production/data/USA/simvars/high/high.20241004.adj_amend.ci 4721
# Variable close is loaded from /home/newprod/production/data/USA/simvars/close/close.20241004.adj_amend.ci 4721
# Variable mktcap is loaded from /home/newprod/production/data/USA/simvars/mktcap/mktcap.20241004.adj_amend.ci 4721
# Variable uopen is loaded from /home/newprod/production/data/USA/simvars/uopen/uopen.20241004.adj_amend.ci 4721
# Variable uvwap is loaded from /home/newprod/production/data/USA/simvars/uvwap/uvwap.20241004.adj_amend.ci 4721
# Variable uclose is loaded from /home/newprod/production/data/USA/simvars/uclose/uclose.20241004.adj_amend.ci 4721
# Variable uvolume is loaded from /home/newprod/production/data/USA/simvars/uvolume/uvolume.20241004.adj_amend.ci 4721
# Variable adjfactor is loaded from /home/newprod/production/data/USA/simvars/adjfactor/adjfactor.20241004.adj_amend.ci 4721
# Variable adjfactor_price_only is loaded from /home/newprod/production/data/USA/simvars/adjfactor_price_only/adjfactor_price_only.20241004.adj_amend.ci 4721
# Variable cashdvd is loaded from /home/newprod/production/data/USA/simvars/cashdvd/cashdvd.20241004.adj_amend.ci 4721
# Variable industry is loaded from /home/newprod/production/data/USA/simvars/industry/industry.20241004.adj_amend.ci 4721
# Variable sector is loaded from /home/newprod/production/data/USA/simvars/sector/sector.20241004.adj_amend.ci 4721
# Variable subindustry is loaded from /home/newprod/production/data/USA/simvars/subindustry/subindustry.20241004.adj_amend.ci 4721
# Variable vwap is loaded from /home/newprod/production/data/USA/simvars/vwap/vwap.20241004.adj_amend.ci 4721
# Variable top100 is loaded from /home/newprod/production/data/USA/simvars/top100/top100.20241004.adj_amend.ci 4721
# Variable top250 is loaded from /home/newprod/production/data/USA/simvars/top250/top250.20241004.adj_amend.ci 4721
# Variable top500 is loaded from /home/newprod/production/data/USA/simvars/top500/top500.20241004.adj_amend.ci 4721
# Variable top1000 is loaded from /home/newprod/production/data/USA/simvars/top1000/top1000.20241004.adj_amend.ci 4721
# Variable top1500 is loaded from /home/newprod/production/data/USA/simvars/top1500/top1500.20241004.adj_amend.ci 4721
# Variable top1750 is loaded from /home/newprod/production/data/USA/simvars/top1750/top1750.20241004.adj_amend.ci 4721
# Variable top2000 is loaded from /home/newprod/production/data/USA/simvars/top2000/top2000.20241004.adj_amend.ci 4721
# Variable top2500 is loaded from /home/newprod/production/data/USA/simvars/top2500/top2500.20241004.adj_amend.ci 4721
# Variable top3000 is loaded from /home/newprod/production/data/USA/simvars/top3000/top3000.20241004.adj_amend.ci 4721
# Variable top500_2000 is loaded from /home/newprod/production/data/USA/simvars/top500_2000/top500_2000.20241004.adj_amend.ci 4721
# Variable growth1200 is loaded from /home/newprod/production/data/USA/simvars/growth1200/growth1200.20241004.adj_amend.ci 4721
# Variable value1200 is loaded from /home/newprod/production/data/USA/simvars/value1200/value1200.20241004.adj_amend.ci 4721
# Variable sp500 is loaded from /home/newprod/production/data/USA/simvars/sp500/sp500.20241004.adj_amend.ci 4721
# Variable ret1 is loaded from /home/newprod/production/data/USA/simvars/ret1/ret1.20241004.adj_amend.ci 4721
# Variable ret5 is loaded from /home/newprod/production/data/USA/simvars/ret5/ret5.20241004.adj_amend.ci 4721
# Variable vol20 is loaded from /home/newprod/production/data/USA/simvars/vol20/vol20.20241004.adj_amend.ci 4721
# Variable locates_ms_avshs is loaded from /home/newprod/production/data/USA/simvars/locates_ms_avshs/locates_ms_avshs.20241004.adj_amend.ci 4721
# Variable locates_ms_rebate is loaded from /home/newprod/production/data/USA/simvars/locates_ms_rebate/locates_ms_rebate.20241004.adj_amend.ci 4721
# Variable barra_hbta is loaded from /home/newprod/production/data/USA/simvars/barra_hbta/barra_hbta.20241004.adj_amend.ci 4721
# Variable barra_beta is loaded from /home/newprod/production/data/USA/simvars/barra_beta/barra_beta.20241004.adj_amend.ci 4721
# Variable barra_srisk is loaded from /home/newprod/production/data/USA/simvars/barra_srisk/barra_srisk.20241004.adj_amend.ci 4721
# Variable barra_trisk is loaded from /home/newprod/production/data/USA/simvars/barra_trisk/barra_trisk.20241004.adj_amend.ci 4721
# Variable barra_volatility is loaded from /home/newprod/production/data/USA/simvars/barra_volatility/barra_volatility.20241004.adj_amend.ci 4721
# Variable barra_momentum is loaded from /home/newprod/production/data/USA/simvars/barra_momentum/barra_momentum.20241004.adj_amend.ci 4721
# Variable barra_size is loaded from /home/newprod/production/data/USA/simvars/barra_size/barra_size.20241004.adj_amend.ci 4721
# Variable barra_sizenonl is loaded from /home/newprod/production/data/USA/simvars/barra_sizenonl/barra_sizenonl.20241004.adj_amend.ci 4721
# Variable barra_tradeact is loaded from /home/newprod/production/data/USA/simvars/barra_tradeact/barra_tradeact.20241004.adj_amend.ci 4721
# Variable barra_growth is loaded from /home/newprod/production/data/USA/simvars/barra_growth/barra_growth.20241004.adj_amend.ci 4721
# Variable barra_earnyld is loaded from /home/newprod/production/data/USA/simvars/barra_earnyld/barra_earnyld.20241004.adj_amend.ci 4721
# Variable barra_value is loaded from /home/newprod/production/data/USA/simvars/barra_value/barra_value.20241004.adj_amend.ci 4721
# Variable barra_earnvar is loaded from /home/newprod/production/data/USA/simvars/barra_earnvar/barra_earnvar.20241004.adj_amend.ci 4721
# Variable barra_leverage is loaded from /home/newprod/production/data/USA/simvars/barra_leverage/barra_leverage.20241004.adj_amend.ci 4721
# Variable barra_currsen is loaded from /home/newprod/production/data/USA/simvars/barra_currsen/barra_currsen.20241004.adj_amend.ci 4721
# Variable barra_yield is loaded from /home/newprod/production/data/USA/simvars/barra_yield/barra_yield.20241004.adj_amend.ci 4721
# Variable barra_nonestu is loaded from /home/newprod/production/data/USA/simvars/barra_nonestu/barra_nonestu.20241004.adj_amend.ci 4721
# Variable barra_ind1_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind1_id/barra_ind1_id.20241004.adj_amend.ci 4721
# Variable barra_ind1_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind1_rev/barra_ind1_rev.20241004.adj_amend.ci 4721
# Variable barra_ind2_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind2_id/barra_ind2_id.20241004.adj_amend.ci 4721
# Variable barra_ind2_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind2_rev/barra_ind2_rev.20241004.adj_amend.ci 4721
# Variable barra_ind3_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind3_id/barra_ind3_id.20241004.adj_amend.ci 4721
# Variable barra_ind3_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind3_rev/barra_ind3_rev.20241004.adj_amend.ci 4721
# Variable barra_ind4_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind4_id/barra_ind4_id.20241004.adj_amend.ci 4721
# Variable barra_ind4_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind4_rev/barra_ind4_rev.20241004.adj_amend.ci 4721
# Variable barra_ind5_id is loaded from /home/newprod/production/data/USA/simvars/barra_ind5_id/barra_ind5_id.20241004.adj_amend.ci 4721
# Variable barra_ind5_rev is loaded from /home/newprod/production/data/USA/simvars/barra_ind5_rev/barra_ind5_rev.20241004.adj_amend.ci 4721
# Variable indNameMap is loaded from /home/newprod/production/data/USA/simvars/indNameMap/indNameMap.20241004.adj_amend.txt 4721
# Variable prod_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_alpha_ids/prod_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_alpha_is_deads is loaded from /home/newprod/production/data/USA/simvars/prod_alpha_is_deads/prod_alpha_is_deads.20241004.adj_amend.mat 4721
# Variable prod_d0_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d0_alpha_ids/prod_d0_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_d1_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d1_alpha_ids/prod_d1_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_post_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_post_alpha_ids/prod_post_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_post_alpha_is_deads is loaded from /home/newprod/production/data/USA/simvars/prod_post_alpha_is_deads/prod_post_alpha_is_deads.20241004.adj_amend.mat 4721
# Variable prod_d0_post_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d0_post_alpha_ids/prod_d0_post_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_d1_post_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d1_post_alpha_ids/prod_d1_post_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_forecast_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_forecast_alpha_ids/prod_forecast_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_forecast_alpha_is_deads is loaded from /home/newprod/production/data/USA/simvars/prod_forecast_alpha_is_deads/prod_forecast_alpha_is_deads.20241004.adj_amend.mat 4721
# Variable prod_d0_forecast_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d0_forecast_alpha_ids/prod_d0_forecast_alpha_ids.20241004.adj_amend.mat 4721
# Variable prod_d1_forecast_alpha_ids is loaded from /home/newprod/production/data/USA/simvars/prod_d1_forecast_alpha_ids/prod_d1_forecast_alpha_ids.20241004.adj_amend.mat 4721
# Variable dates is loaded from /home/newprod/production/data/USA/simvars/dates/dates.20241004.adj_amend.mat 4721
# Shift data for d0
# Shifting spread_timeweighted_allday by one day
# Shifting mktcap by one day
# Shifting top100 by one day
# Shifting top250 by one day
# Shifting top500 by one day
# Shifting top1000 by one day
# Shifting top1500 by one day
# Shifting top1750 by one day
# Shifting top2000 by one day
# Shifting top2500 by one day
# Shifting top3000 by one day
# Shifting top500_2000 by one day
# Shifting growth1200 by one day
# Shifting value1200 by one day
# Shifting sp500 by one day
# Shifting locates_ms_avshs by one day
# Shifting locates_ms_rebate by one day
# Shifting barra_hbta by one day
# Shifting barra_beta by one day
# Shifting barra_srisk by one day
# Shifting barra_trisk by one day
# Shifting barra_volatility by one day
# Shifting barra_momentum by one day
# Shifting barra_size by one day
# Shifting barra_sizenonl by one day
# Shifting barra_tradeact by one day
# Shifting barra_growth by one day
# Shifting barra_earnyld by one day
# Shifting barra_value by one day
# Shifting barra_earnvar by one day
# Shifting barra_leverage by one day
# Shifting barra_currsen by one day
# Shifting barra_yield by one day
# Shifting barra_nonestu by one day
# Shifting barra_ind1_id by one day
# Shifting barra_ind1_rev by one day
# Shifting barra_ind2_id by one day
# Shifting barra_ind2_rev by one day
# Shifting barra_ind3_id by one day
# Shifting barra_ind3_rev by one day
# Shifting barra_ind4_id by one day
# Shifting barra_ind4_rev by one day
# Shifting barra_ind5_id by one day
# Shifting barra_ind5_rev by one day
# NOT Shifting prod_forecast_alpha_ids
# NOT Shifting prod_forecast_alpha_is_deads
# NOT Shifting prod_d0_forecast_alpha_ids
# NOT Shifting prod_d1_forecast_alpha_ids
# The alpha list is reconciled
# Alpha list size: 119487
# Rendering ndarray read-only

# %% [markdown]
# ## **Mask**
#
# Most data variables at Trexquant are 2D matrices with dimensions _num\_stocks_ x _num\_dates_. We want to filter on the dates when earnings were announced and convert the 2D matrix to a vector so that it can be used in an ML model.
#
# To find the earnings date we use the data variable [trading_days_til_next_ann](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/trading_days_til_next_ann/). We also require the time of announcement which we get from the data variable [fs_next_ann_time](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/fs_next_ann_time/). We use the following logic to construct the mask:
# 1. If the annoucement time is before the trading time (1500), set the earnings return day as today.
# 2. If the annoucement time is after the trading time (1500), set the earnings return day as the next day.
#
# The code in the cell below constructs the mask

# %%
### ---- ---- ---- ---- No need to modify the code below ---- ---- ---- ---- ###

# contruct earning mask based on trading_days_til_next_ann
valid_mask = (data['load_simvar_hhmm']('trading_days_til_next_ann') == 1)
fs_next_ann_time = data['load_simvar_hhmm']('fs_next_ann_time')

# based on trading_days_til_next_ann and fs_next_ann_time
# delay one day if earnings is announced after we trade
valid_effect_mask = np.zeros_like(valid_mask, dtype=np.float32)
for si, di in zip(*np.where((valid_mask == 1) & (data['valids']))):

    # skip if we are unable to get the target
    if di + data['delay'] >= data['numdates']:
        continue

    time = fs_next_ann_time[si, di]

    if time <= 1500:
        target_di = di
    elif time > 1500 and di + 1 < data['numdates']:
        target_di = di+1
    if valid_effect_mask[si, target_di] != 1:
        valid_effect_mask[si, target_di] = 1
        
bet_days_mask = valid_effect_mask==1
bet_days_mask = op.at_nan2zero(bet_days_mask*1.0)
flatten_mask = (bet_days_mask==1.0)

# %% [markdown]
# ## **Target**
#
# For this challenge we will use one-day forward ret1_excess as the target
# - target columns: `target`, which is the forward [ret1_excess](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/ret1_excess/)
# - dates: `dates` column is the masked dates, which is the day we want to enter our position before the earning announcement.
# - stock index: `si`
# - date index: `di`
# - `[si,di]` data point indicates that we want to enter into the position for the stock at si th index and di th date just before the company announces its results

# %%
### ---- ---- ---- ---- No need to modify the code below ---- ---- ---- ---- ###

ret1_excess = data['load_simvar_hhmm']('ret1_excess')
fwd_ret = op.ts_delay((ret1_excess),-1) # one day forward ret1_excess

# modify mask to remove points where target is invalid
flatten_mask[np.isnan(fwd_ret)] = False  
target = fwd_ret[flatten_mask]

# put target into the dataframe
df = pd.DataFrame()
df['target'] = target

num_of_stocks, num_of_dates = ret1_excess.shape
si_list = np.array([list(np.arange(num_of_stocks))]*num_of_dates).transpose()
di_list = np.array([list(np.arange(num_of_dates))]*num_of_stocks)

df['si'] = si_list[flatten_mask]
df['di'] = di_list[flatten_mask]
dates_mat = np.tile(data['dates'], (num_of_stocks,1))
df['dates'] = dates_mat[flatten_mask]

# %% [markdown]
# ## **Features**
#
# For this challenge you can use any of the data variables available in the [data description](https://trexsim.com/trexsim/pysim/data_description/USA/).
# You may further apply any transformations to the data variables that you deem appropriate.
#
# Please keep in mind that **all features used must be dimensionless**. Features that have dimensions of price of number of shares are subject to adjustment which introduces a forward bias. An easy way to check if a data variable is subject to adjustment is to check if there is anything in the `adjfactor_type` column in the data description.
# Features which are subject to adjustment can be normalized using operators like `ts_zscore`, `ts_norm` and `ts_std_normalized`. Find all available operators in [operators list](https://www.trexsim.com/trexsim/pysim/comptutorial/operators.html).
#
# You can combine existing features and apply operators to make new features as long as the transformations are reasonable.
#
# In the followint cell, you will see 3 feature used in the benchmark model.
# - [ret1](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/ret1/): On day return.
# - [linkup_job_active_count](https://www.trexsim.com/trexsim/pysim/data_description/variable/USA/linkup_job_active_count/): number of active jobs.

# %%
### ---- ---- ---- ---- Featurs used in the Benchmark model ---- ---- ---- ---- ###

####### feature 1: tsz_ret1
ret1 = data['load_simvar_hhmm']('ret1')                    # Load data variable
tsz_ret1 = op.at_nan2zero(op.ts_zscore(ret1, 21))          # Calculate the feature
df['tsz_ret1'] = tsz_ret1[flatten_mask]                    # Apply the mask to the feature and save it in the dataframe.

####### feature 2: tsz_ret1_delay1
tsz_ret1_d1 = op.at_nan2zero(op.ts_zscore(op.ts_delay(ret1,1), 21))       
df['tsz_ret1_d1'] = tsz_ret1_d1[flatten_mask] 

####### feature 3: linkup_job_active_count
linkup_job_active_count = data['load_simvar_hhmm']('linkup_job_active_count')
linkup_job_active_count = op.at_nan2zero(op.ts_zscore(op.ts_fill(linkup_job_active_count), 21))
df['linkup_job_active_count'] = linkup_job_active_count[flatten_mask]

# name of all features
features_ls = [col for col in df.columns if col not in ['target', 'si', 'di', 'dates']]
print(f"Current features: {features_ls}")
# Out:
# Current features: ['tsz_ret1', 'tsz_ret1_d1', 'linkup_job_active_count']

# %% [markdown]
# ### The industry Splitover effect

# %%
def safe_div(x, y):
    y = np.where(np.abs(y) < 1e-9, np.nan, y)
    return x / y

import pandas as pd
from tqdm import tqdm
import scipy

def groupMean(data, group):
    gMean = np.full(data.shape, np.nan, order = "F", dtype = np.float32)
    for di in range(gMean.shape[1]):
        df = pd.DataFrame({"data": data[:, di], "group": group[:, di]})
        gMean[:, di] = df.groupby("group")["data"].transform("mean").values
    return gMean

# %%
def stock_map_compressed_to_uncompressed(stock_list_compressed, valid_stock_mask):
    ### function to map compressed ticker rows to uncompressed ticker rows
    print('converting compressed stock index to uncompressed index')

    stock_mask_cumulative = np.cumsum(valid_stock_mask * 1) - 1
    stock_list_uncompressed = np.copy(stock_list_compressed * 0)

    number_of_stocks = stock_list_compressed.size
    print('number_of_stocks = ', number_of_stocks)

    for ii in range(number_of_stocks):
        compressed_indx = stock_list_compressed[ii]
        uncompressed_indx = np.where(stock_mask_cumulative == compressed_indx)[0][0]

        stock_list_uncompressed[ii] = uncompressed_indx

    # print('compressed indx (input)',stock_list_compressed)
    # print('uncompressed indx (output)',stock_list_uncompressed)

    return stock_list_uncompressed

compressedlist = stock_map_compressed_to_uncompressed(np.arange(ret1.shape[0]), data['valid_stock_mask'])
# Out:
# converting compressed stock index to uncompressed index
# number_of_stocks =  11440

# %%
from tqdm import tqdm
def relationMean(relation, data, transpose=False):
    '''
    relation: the 3D variable that describes the relationship between the firms
    data: the data that we want to take the mean
    '''
    numstocks, numdates = data.shape
    re_mean = np.zeros((numstocks, numdates))

    for date_index in tqdm(range(numdates)):
        sparse_matrix = relation[date_index].tocsc()  # 使用更适合列操作的格式
        sparse_matrix = sparse_matrix[compressedlist, :][:, compressedlist]

        weighted_now = np.where(data[:, date_index] != 0, 1.0, 0.0)
        # 计算所有股票在该日期的markit_Milliq总和
        if transpose:
            sum_relation = sparse_matrix.T.dot(data[:, date_index])
        else:
            sum_relation = sparse_matrix.dot(data[:, date_index])

        if transpose:
            count_related_stocks = sparse_matrix.T.dot(weighted_now)
        else:
            count_related_stocks = sparse_matrix.dot(weighted_now)

        # 避免除以零，对于没有相关股票的情况，我们设为0或其他默认值
        with np.errstate(divide='ignore', invalid='ignore'):
            average_relation = np.true_divide(sum_relation, count_related_stocks)
            average_relation[~np.isfinite(average_relation)] = 0  # 将无穷大和NaN值设为0

        re_mean[:, date_index] = average_relation

    return re_mean

# %% [markdown]
# ### feature1: - industry average of already ann's this quarter's earning_jump

# %% [markdown]
# ### feature3:-take mean of the already announced's ret20 on the customers

# %%
ret= data['load_simvar_hhmm']('ret1_excess')
last_ann= op.ts_fill(op.at_zero2nan(op.ts_delay(bet_days_mask,1)* ret))
subindustry = data['load_simvar_hhmm']('subindustry')
since_qua= data['load_simvar_hhmm']('days_since_first_trading_day_of_quarter')
since_ann= data['load_simvar_hhmm']('trading_days_since_last_ann')
ann_ret_q=op.at_nan2zero(((since_ann-since_qua)<=0)*(last_ann))

ret_already_jump = np.where((since_ann-since_qua)<=0, last_ann, np.nan)
indavg_retother = groupMean(ret_already_jump, subindustry)
df['indavg_retother'] = op.at_nan2zero(indavg_retother)[flatten_mask]

# %%
revere_customer2supplier = data['load_simvar_hhmm']('revere_customer2supplier')
avg_customer_ret_already = relationMean(revere_customer2supplier, ann_ret_q, True)
df['avg_customer_ret_already'] = op.at_nan2zero(avg_customer_ret_already)[flatten_mask]

# %%
ret= data['load_simvar_hhmm']('ret1_excess')
last_ann= op.ts_fill(op.at_zero2nan(op.ts_delay(bet_days_mask,1)* ret))
industry= data['load_simvar_hhmm']('sector')
since_qua= data['load_simvar_hhmm']('days_since_first_trading_day_of_quarter')
since_ann= data['load_simvar_hhmm']('trading_days_since_last_ann')
ret1_jump =op.at_nan2zero(((since_ann-since_qua)<=0)*(last_ann))

# %%
barra_similarity = data['load_simvar_hhmm']('barra_factor_similarity_relationship_boolThres05PosOnly')
avg_barrasimilar_ret1_jump = relationMean(barra_similarity, ret1_jump, False)
df['avg_barrasimilar_ret1_jump'] = op.at_nan2zero(avg_barrasimilar_ret1_jump)[flatten_mask]
# Out:
# 100%|██████████| 4721/4721 [00:36<00:00, 130.76it/s]

# %%
barra_similarity = data['load_simvar_hhmm']('barra_factor_similarity_relationship_boolThres05PosOnly')
avg_barrasimilar_ret1_jump = relationMean(barra_similarity, ret1_jump, False)
df['avg_barrasimilar_ret1_jump'] = op.at_nan2zero(avg_barrasimilar_ret1_jump)[flatten_mask]

# %%
# ret5_excess = data['load_simvar_hhmm']('ret5_excess')
# avg_barrasimilar_ret5_excess = relationMean(barra_similarity, ret5_excess, False)
# df['avg_barrasimilar_ret5_excess'] = op.at_nan2zero(avg_barrasimilar_ret5_excess)[flatten_mask] outperformed
# Out:
# 100%|██████████| 4721/4721 [00:36<00:00, 127.93it/s]

# %%
gc.collect()
# Out:
# 48298

# %% [markdown]
# ### feature4:-take the industry mean of the yoy sale growth rate on the already announced companies

# %% [markdown]
# ### Add or delete features

# %%
features_ls = [col for col in df.columns if col not in ['target', 'si', 'di', 'dates','avg_customer_ret_already','indavg_retother','avg_barrasimilar_ret1_jump']]
print(f"Current features: {features_ls}")
# Out:
# Current features: ['tsz_ret1', 'tsz_ret1_d1', 'linkup_job_active_count', 'markit_Milliq_std_5_similarity']

# %% [markdown]
# ## Feature correlation analysis

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

def dataframe_summary(df):


    # 打印每列的统计量
    print("Statistics:")
    print(df.describe())
    print()

    # 计算每列的NAN值个数
    print("Number of NANs:")
    print(df.isnull().sum())
    print()

    # 计算每列的0值个数
    print("Number of 0:")
    print((df == 0).sum())
    print()

    # 绘制箱线图
    df.boxplot()
    plt.title("Boxplot of DataFrame")
    plt.xticks(rotation=45)
    plt.show()

# 查看DataFrame的摘要信息
dataframe_summary(df[features_ls])
# Out:
# Statistics:
#         tsz_ret1  tsz_ret1_d1  linkup_job_active_count  \
# count 150113.000   150113.000               150113.000
# mean      -0.013       -0.017                    0.043
# std        1.194        1.009                    0.882
# min       -4.358       -4.218                   -4.364
# 25%       -0.730       -0.659                    0.000
# 50%       -0.025       -0.027                    0.000
# 75%        0.705        0.622                    0.000
# max        4.352        4.343                    4.364
#
#        markit_Milliq_std_5_similarity
# count                      150113.000
# mean                            0.001
# std                             0.021
# min                            -0.631
# 25%                             0.000
# 50%                             0.000
# 75%                             0.000
# max                             0.887
#
# Number of NANs:
# tsz_ret1                          0
# tsz_ret1_d1                       0
# linkup_job_active_count           0
# markit_Milliq_std_5_similarity    0
# dtype: int64
#
# Number of 0:
# tsz_ret1                             204
# tsz_ret1_d1                          213
# linkup_job_active_count            86016
# markit_Milliq_std_5_similarity    140995
# dtype: int64

# %% [markdown]
# ### Plot the correlations

# %%
# %matplotlib inline
plt.figure(figsize=(5, 4)) # adjust the figure size of the heatmap
correlation_matrix = df[features_ls].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## **Training and validation**
# - Training period: From 2006 to 2016 (11 years)
# - Validation period: From 2017 to 2020 (4 years)

# %%
train_startdate = 20060101
train_enddate = 20161231

valid_startdate = 20170101
valid_enddate = 20201231

# split the df according to the periods of train/valid
train_mask = (df['dates'] >= train_startdate) & (df['dates'] <= train_enddate)
valid_mask = (df['dates'] >= valid_startdate) & (df['dates'] <= valid_enddate)

df_train = df[train_mask]
df_valid = df[valid_mask]
        
X_train,Y_train = df_train[features_ls].to_numpy(),df_train['target'].to_numpy()
X_valid,Y_valid = df_valid[features_ls].to_numpy(),df_valid['target'].to_numpy()

train_si,train_di = df_train['si'].values, df_train['di'].values
valid_si,valid_di = df_valid['si'].values, df_valid['di'].values

# %% [markdown]
# ## **Model**

# %%
### ---- ---- ---- ---- Train your Model ---- ---- ---- ---- ###

from sklearn.ensemble import GradientBoostingRegressor

# train the model
regressor = GradientBoostingRegressor(n_estimators=400, learning_rate=0.10, max_depth=1, random_state=42)
regressor.fit(X_train, Y_train)

# predict
YPRED_train = regressor.predict(X_train)
YPRED_valid = regressor.predict(X_valid)

# alpha
alpha = np.full_like(data['ret1'], np.nan, dtype='float32', order='F')
alpha[train_si, train_di] = YPRED_train
alpha[valid_si, valid_di] = YPRED_valid

# accuracy
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, f1_score
acc_train = accuracy_score(Y_train>=0, YPRED_train>=0)
acc_valid = accuracy_score(Y_valid>=0, YPRED_valid>=0)
print(f'Accuracy Train: {acc_train :>.3%}')
print(f'Accuracy Valid: {acc_valid :>.3%}')
# Out:
# Accuracy Train: 51.408%
# Accuracy Valid: 51.347%

# %% [markdown]
# ## **Simulation**
#
# ##### Post Processing (PP) function
# - PP function applies the final risk-management constraints on the signal and makes our signal tradeable in real markets
# - PP function reduces the turnover and increases the liquidity which reduces the slippage costs

# %%
# PP function - No need to modify the code below

def post_processing(data, preA, booksize):
    lookback = 252
    
    apply_locates = data['apply_locates']
    preA1 = np.copy(preA)
    preA1 *= data['valids']
  
    postA = op.at_nan2zero(preA1)
    postA = op.ts_mean_exp(op.at_nan2zero(postA), 5, 2/5)
    
    postA = op.cs_poslimit(postA, 0.1)
    postA = op.cs_indneut(postA, data['sector'])
    postA = op.cs_shrink_balance(postA)                                            

    long_scaler = op.ts_max(np.nansum(postA*(postA>0),axis=0),lookback)            
    short_scaler = op.ts_max(np.nansum(np.abs(postA)*(postA<0),axis=0),lookback)   
    scaler = np.maximum(long_scaler,short_scaler)                                  
    postA = postA/scaler * booksize                                                
    
    postA = op.op_vmcont(postA, data['valids'], data['close'], data['vol20'],
                         maxtrd=0.05*(booksize/1e9), maxpos=0.5*(booksize/1e9))
    postA = op.tc_hump(postA, data['close'], hump_factor=1.0)                      
    postA = op.cs_shrink_balance(postA)                                            

    long_scaler = op.ts_max(np.nansum(postA*(postA>0),axis=0),lookback)
    short_scaler = op.ts_max(np.nansum(np.abs(postA)*(postA<0),axis=0),lookback)
    scaler = np.maximum(long_scaler,short_scaler)
    postA = postA/scaler * booksize

    postA = op.cs_poslimit(postA, 0.1)
    postA = op.cs_shrink_balance(postA)                                            
    postA = apply_locates(postA, data, data['locate_utilization_rate'], data['max_rebate_rate'])
    return postA

# %%
### ---- ---- ---- ---- No need to modify the code below ---- ---- ---- ---- ###
# simulation
postA = post_processing(data,alpha,data['booksize'])
postA[:, np.where(data['dates']>valid_enddate)[0][0]:]=np.nan # nan out values after valid_enddate
simres = op.op_simulate(data,postA,0,liq_on_valid_days=True,calc_liqn=True,slippage=True, slippage_model='fraction_spread', fraction_spread=0.2)

# simulation results
simres_train = op.cut_simres(simres,startdate=train_startdate,enddate=train_enddate)
simres_valid = op.cut_simres(simres,startdate=valid_startdate,enddate=valid_enddate)

# pnl plots
# %matplotlib inline
op.op_plot(op.cut_simres(simres,startdate=train_startdate,enddate=train_enddate),label='train period')
op.op_plot(op.cut_simres(simres,startdate=valid_startdate,enddate=valid_enddate),label='valid period')

# %% [markdown]
# ## **Summary**

# %%
# Summary on the Metrics
metrics = ['ir','ret','tvr','dd','liqn']
metrics_train = [acc_train*100]+[simres_train[mtc][-1] if isinstance(simres_train[mtc], np.ndarray) else simres_train[mtc] for mtc in metrics]
metrics_valid = [acc_valid*100]+[simres_valid[mtc][-1] if isinstance(simres_valid[mtc], np.ndarray) else simres_valid[mtc] for mtc in metrics]

pd.options.display.float_format = '{:.3f}'.format
simres_df = pd.DataFrame({"train":metrics_train,"valid":metrics_valid}, index=['accuracy']+metrics)
display(simres_df.T)
# Out:
#        accuracy    ir   ret   tvr     dd   liqn
# train    51.408 0.095 0.160 0.383 16.034 40.767
# valid    51.347 0.083 0.127 0.339  6.924 40.767
